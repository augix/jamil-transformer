# %%
from train import train_model
from config import get_config

# additional config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 20

train_model(cfg)
# Out:
# ...
# Processing Epoch 04:  67%|██████▋   | 9999/15000 [02:53<01:31, 54.69it/s, loss=3.168]
# --------------------------------------------------------------------------------
#    Initial: G87 G90 G26 G81 G71 G6 G37 G15 G2 G19 G9 G52 G73 G72 G51 G78 G29 G84 G11 G25 G33 G22 G36 G82 G97 G1 G30 G61 G91 G55 G60 G77 G4 G100 G56 G67 G66 G65 G57 G94 G59 G62 G68 G44 G58 G88 G70 G27 G93 G63 G12 G92 G48 G49 G96 G40 G10 G89 G47 G95 G35 G43 G53 G86 G64 G28 G98 G3 G75 G83 G34 G24 G16 G7 G46 G42 G18 G31 G38 G13 G20 G39 G32 G8 G54 G21 G99 G14 G80 G45 G79 G5 G17 G41 G23 G74 G85 G69 G50 G76
#    Predict: G87 G90 G81 G6 G26 G71 G9 G2 G37 G52 G19 G73 G72 G11 G84 G29 G78 G25 G15 G30 G82 G97 G33 G51 G22 G1 G60 G91 G36 G67 G77 G61 G100 G4 G55 G56 G66 G94 G65 G57 G62 G68 G70 G44 G27 G58 G59 G63 G92 G3 G64 G21 G12 G89 G12 G89 G7 G39 G35 G18 G31 G74 G39 G31 G18 G88 G39 G85 G20 G75 G43 G48 G42 G95 G20 G75 G5 G80 G32 G10 G18 G88 G75 G42 G35 G8 G85 G20 G54 G14 G16 G7 G53 G76 G80 G48 G45 G87 G32 G16
# ...
